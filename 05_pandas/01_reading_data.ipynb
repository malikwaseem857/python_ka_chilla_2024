# %% [markdown]
# # Pandas library

# %% [markdown]
# Step-1: Importing the library

# %%
import pandas as pd

# %%
# importing data from clipboard
df = pd.read_clipboard()
df
# Out:
#     # importing                 data  from  clipboard
# 0  df         =  pd.read_clipboard()   NaN        NaN
# 1  df      None                 None   NaN        NaN

# %% [markdown]
# # importing data from excel file

# %%
import pandas as pd
df_excel = pd.read_excel('../04_libraries/dataframes/titanic.xlsx', sheet_name=0) # sheet_name=0 is default you can also change the sheet name = "Sheet1"
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd
df_excel = pd.read_excel('../04_libraries/dataframes/titanic.xlsx')
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # CSV and TSV files

# %%
# load csv data
df_csv = pd.read_csv('../00_datasets/titanic.csv')
df_csv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# load tsv data
df_tsv = pd.read_csv('../00_datasets/titanic.txt', sep='\t')
df_tsv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Dummy Dataset

# %%
# create a dataframe from a dictionary for the people ages and names
data = {'Name': ['Muhammad', 'Ali', 'Ahmad', 'Minahil'],
        'Age': [28, 23, 25, 27],
        'Weight': [70, 75, 80, 65]
        }
data
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      70
# 1       Ali   23      75
# 2     Ahmad   25      80
# 3   Minahil   27      65

# %%
df.to_clipboard()

# %%
df.to_excel('../00_datasets/people.xlsx', index=False)
df.to_csv('../00_datasets/people.csv', index=False)

# %% [markdown]
# # Advance Datset Reading from Excel

# %%
string = "Aammar\nAli\nAhmad\nMinahil"
print(string)
# Out:
# Aammar
# Ali
# Ahmad
# Minahil

# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\SAMIA NOREEN\Desktop\python_ka_chilla_2024\00_datasets\world_papulation_excel_workbook.xls",
    engine="xlrd"
)

print(df)
# Out:
#     Unnamed: 0                                    Population 2022  Unnamed: 2  \
# 0          NaN                                                NaN         NaN
# 1          NaN                                                NaN         NaN
# 2          NaN                                            Ranking         NaN
# 3          NaN                                                NaN         NaN
# 4          IND                                                  1         NaN
# ..         ...                                                ...         ...
# 235        HIC                                                NaN         NaN
# 236        NaN                                                NaN         NaN
# 237        NaN  a. Excludes Abkhazia and South Ossetia.  b. Ex...         NaN
# 238        NaN                                                NaN         NaN
# 239        NaN  http://data.worldbank.org/data-catalog/world-d...         NaN
#
# ...

# %%
# read csv with spaces in name
df = pd.read_csv(r"C:\Users\SAMIA NOREEN\Desktop\python_ka_chilla_2024\00_datasets\countries of the world.csv")
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %% [markdown]
# # Reading Tabluar Data

# %%
import pandas as pd

df_tabulated = pd.read_table("../00_datasets/titanic.txt", sep="\t", header=0)
df_tabulated
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Json file reading

# %%
import pandas as pd
df = pd.read_json('../00_datasets/json_sample.json')
df
# Out:
#                   title      genre       gross  imdb_metascore  popcorn_score  \
# 0             12 Strong     Action    $453,173              54             72
# 1     A Fantastic Woman      Drama     $87,000              78             83
# 2  Call Me By Your Name      Drama  $1,000,000              93             87
# 3          Paddington 2  Animation    $184,414              88             89
#
#   rating  tomato_score
# 0      R            54
# 1      R            90
# 2      R            96
# 3     PG           100
